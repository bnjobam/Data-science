# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal as norm1
from scipy import stats
import seaborn as sns
sns.set_style('white')
# %matplotlib inline
import random
import math

# %%
D = 2
K = 3
N = int(K*1e4)

X0 = np.random.randn((N//K),D) + np.array([2,2])
X1 = np.random.randn((N//K),D) + np.array([0,-2])
X2 = np.random.randn((N//K),D) + np.array([-2,2])
X = np.vstack((X0,X1,X2))

y = np.array([0]*(N//K) + [1]*(N//K) + [2]*(N//K))

plt.figure(figsize = (12,9))
plt.scatter(X[:,0],X[:,1],c = y,alpha = 0.3333)

# %%
sns.distplot(X[:,0],fit=stats.norm,bins=60,kde=False)

# %%
x=np.linspace(min(X[:,0]),max(X[:,0]),300)
plt.plot(x,stats.norm.pdf(x,np.mean(X[:,0]),np.std(X[:,0])))
sns.distplot(X[:,0],bins=100,kde=False, norm_hist=True)

# %%
k=3
mix=[1/k]*k#np.random.uniform(0,1,k)
mu=np.random.uniform(min(X[:,0]),max(X[:,0]),k)
std=np.random.uniform(0.1,np.std(X[:,0]),k)
prob=np.zeros((len(X[:,0]),k))
def expstep(prob,std,mu,mix,k,X):
    for i in range(len(X)):
        for j in range(k):
            den=[mix[a]*stats.norm.pdf(X[i],mu[a],std[a]) for a in range(k)]
            prob[i,j]=mix[j]*stats.norm.pdf(X[i],mu[j],std[j])/sum(den)
    return prob
def maxstep(prob,X,k):
    for i in range(k):
        mu[i]=sum(prob[:,i]*X)/sum(prob[:,i])
        std[i]=np.sqrt(sum(prob[:,i]*(X-mu[i])**2)/sum(prob[:,i]))
        mix=prob.mean(axis=0)
    return mu,std,mix

# %%
time=dt.now()
for iteration in range(35):
    expstep(prob,std,mu,mix,k,X[:,0])
    maxstep(prob,X[:,0],k)
timediff=(dt.now()-time).seconds
print('{:2.4f}' .format(timediff))
# Out:
# 2024.0000

# %%
x=np.linspace(min(X[:,0]),max(X[:,0]),300)
plt.plot(x,sum([stats.norm.pdf(x,mu[i],std[i])*mix[i] for i in range(k)]))
sns.distplot(X[:,0],bins=100,kde=False, norm_hist=True)

# %%
x=np.linspace(min(X[:,0]),max(X[:,0]),100)
plt.plot(x,sum([stats.norm.pdf(x,mu[i],std[i])*mix[i] for i in range(k)]))
sns.distplot(X[:,0],bins=100,kde=False, norm_hist=True)

# %%
import scipy

# %%
mm=np.random.uniform(1,4,3)

cons=[{'type':'eq','fun':lambda mm: sum(mm)-10},{'type':'ineq','fun':lambda mm: sum(mm)-5}]
bnds=((3,5),(2,5),(2,5))

# %%
def funct(mm):
    return np.prod(mm)
time=dt.now()
minimal=scipy.optimize.minimize(funct,mm,method='slsqp',bounds=bnds,constraints=cons)
timedif=(dt.now()-time).seconds

# %%
timedif
# Out:
# 0

# %%
minimal
# Out:
#      fun: 31.25000000000004
#      jac: array([ 6.25, 12.5 , 12.5 ])
#  message: 'Optimization terminated successfully.'
#     nfev: 16
#      nit: 3
#     njev: 3
#   status: 0
#  success: True
#        x: array([5. , 2.5, 2.5])

# %%
def fxn(x):
    return x[0]**2+x[1]**2+6

# %%
cons=({'type':'ineq','fun':lambda x: -x[0]**2-x[1]**2-2},{'type':'ineq','fun':lambda x: x[0]**2-x[1]-2})
bnds=((0,None),(1,None))
res=scipy.optimize.minimize(fxn,(2,2),method='slsqp',bounds=bnds, constraints=cons)

# %%
res
# Out:
#      fun: 9.9999999999926
#      jac: array([3.46410167, 2.        ])
#  message: 'Optimization terminated successfully.'
#     nfev: 20
#      nit: 9
#     njev: 5
#   status: 0
#  success: True
#        x: array([1.73205081, 1.        ])

# %%
sigma
# Out:
# array([1.13236074, 1.11360401, 1.46236149])

# %%
k1=3
N,D=X.shape
mix1=[1/k1]*k1#np.random.uniform(0,1,k)
mu1=np.random.randn(k,D)#uniform(min(X[:,0]),max(X[:,0]),k)
std1=[np.matlib.identity(D)]*k
prob1=np.zeros((k1,N))

def covariance(X):
    d=X.shape[1]
    return np.cov([X[:,i] for i in range(d)])
def expstep1(prob1,std1,mu1,mix1,k1,X):
    for j in range(k):
        den=mix1[j]*norm1.pdf(X,mu1[j],std1[j])
        prob1[j,:]=den/sum(den)#(mix1[j]*norm1.pdf(X,mu1[j],std1[j])).sum(keepdims=True,axis=0)
    return prob1
def maxstep1(prob1,X,k1):
    for i in range(k1):
        mu1[i,:]=(X.T*prob1[i,:]).sum(axis=1)#/prob1[i,:].sum()
        std1[i]=covariance(((X-mu1[i]).T*prob1[i,:]).T)#np.sqrt(sum(prob[:,i]*(X-mu[i])**2)/sum(prob[:,i]))
        mix1=prob1.mean(axis=0)
    return mu1,std1,mix1

# %%
for iteration in range(5):
    expstep1(prob1,std1,mu1,mix1,k1,X)
    maxstep1(prob1,X,k1)
# Out:
# C:\Users\My PC\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: RuntimeWarning: invalid value encountered in true_divide
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-102-e8c67341fff9> in <module>
#       1 for iteration in range(5):
# ----> 2     expstep1(prob1,std1,mu1,mix1,k1,X)
#       3     maxstep1(prob1,X,k1)
#
# <ipython-input-100-48dd19c81a42> in expstep1(prob1, std1, mu1, mix1, k1, X)
#      11 def expstep1(prob1,std1,mu1,mix1,k1,X):
#      12     for j in range(k):
# ---> 13         den=mix1[j]*norm1.pdf(X,mu1[j],std1[j])
#      14         prob1[j,:]=den/sum(den)#(mix1[j]*norm1.pdf(X,mu1[j],std1[j])).sum(keepdims=True,axis=0)
#      15     return prob1
#
# ~\Anaconda3\lib\site-packages\scipy\stats\_multivariate.py in pdf(self, x, mean, cov, allow_singular)
#     511         dim, mean, cov = self._process_parameters(None, mean, cov)
# ...

# %%
std1
# Out:
# [array([[nan, nan],
#         [nan, nan]]), array([[nan, nan],
#         [nan, nan]]), array([[nan, nan],
#         [nan, nan]])]

# %%
covariance(X-X.mean())
# Out:
# array([[3.68015312e+00, 3.74856954e-03],
#        [3.74856954e-03, 4.57389038e+00]])

# %%
norm1.pdf(X, mu1[1],(std1)[1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-4995b52558f1> in <module>
# ----> 1 norm1.pdf(X, mu1[1],(std1)[1])
#
# ~\Anaconda3\lib\site-packages\scipy\stats\_multivariate.py in pdf(self, x, mean, cov, allow_singular)
#     511         dim, mean, cov = self._process_parameters(None, mean, cov)
#     512         x = self._process_quantiles(x, dim)
# --> 513         psd = _PSD(cov, allow_singular=allow_singular)
#     514         out = np.exp(self._logpdf(x, mean, psd.U, psd.log_pdet, psd.rank))
#     515         return _squeeze_output(out)
#
# ~\Anaconda3\lib\site-packages\scipy\stats\_multivariate.py in __init__(self, M, cond, rcond, lower, check_finite, allow_singular)
#     150         # Note that eigh takes care of array conversion, chkfinite,
#     151         # and assertion that the matrix is square.
# ...

# %%
d=norm1.pdf(X,mu1[1],(std1)[1])
t=mix1[1]*d/(mix1[1]*d.sum(axis=0))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-f458048a79aa> in <module>
# ----> 1 d=norm1.pdf(X,mu1[1],(std1)[1])
#       2 t=mix1[1]*d/(mix1[1]*d.sum(axis=0))
#
# ~\Anaconda3\lib\site-packages\scipy\stats\_multivariate.py in pdf(self, x, mean, cov, allow_singular)
#     511         dim, mean, cov = self._process_parameters(None, mean, cov)
#     512         x = self._process_quantiles(x, dim)
# --> 513         psd = _PSD(cov, allow_singular=allow_singular)
#     514         out = np.exp(self._logpdf(x, mean, psd.U, psd.log_pdet, psd.rank))
#     515         return _squeeze_output(out)
#
# ~\Anaconda3\lib\site-packages\scipy\stats\_multivariate.py in __init__(self, M, cond, rcond, lower, check_finite, allow_singular)
#     150         # Note that eigh takes care of array conversion, chkfinite,
#     151         # and assertion that the matrix is square.
# ...

# %%
(X.T*prob1[1,:]).sum(axis=1)/prob1[i,:].sum()
# Out:
# array([ 0.36731131, -1.43139396])

# %%
mu1=np.ones((k1,D))
prob1=np.ones((k1,N))/N
for i in range(k1):
    mu1[i,:]=(X.T*prob1[i,:]).sum(axis=1)/prob1[i,:].sum()
    std1[i,:]=covariance((prob1[i,:]*(X-mu1[i,:]).T).T)

# %%
covariance((X.T*prob1[1,:]).T)
# Out:
# array([[2.69455245e-09, 7.22627516e-10],
#        [7.22627516e-10, 4.10867979e-09]])

# %%
den=norm1.pdf(X,mu1[j],std1[j])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-d9d7e03c7538> in <module>
# ----> 1 den=norm1.pdf(X,mu1[j],std1[j])
#
# ~\Anaconda3\lib\site-packages\scipy\stats\_multivariate.py in pdf(self, x, mean, cov, allow_singular)
#     511         dim, mean, cov = self._process_parameters(None, mean, cov)
#     512         x = self._process_quantiles(x, dim)
# --> 513         psd = _PSD(cov, allow_singular=allow_singular)
#     514         out = np.exp(self._logpdf(x, mean, psd.U, psd.log_pdet, psd.rank))
#     515         return _squeeze_output(out)
#
# ~\Anaconda3\lib\site-packages\scipy\stats\_multivariate.py in __init__(self, M, cond, rcond, lower, check_finite, allow_singular)
#     150         # Note that eigh takes care of array conversion, chkfinite,
#     151         # and assertion that the matrix is square.
# ...

# %%
from datetime import datetime as dt

# %%
den=[]
for s in range(3000):
    den.append(norm1.pdf(X[s],mu1[1],std1[1]))

# %% [markdown]
# $5\sqrt{3x}+|2x^2|-\frac{3x}{2}$
